# %% [markdown]
# # MNIST CNN Baseline
# A compact starter notebook for training a CNN on MNIST with PyTorch.

# %%
# !python -m pip install -r ../requirements.txt

# %%
# !python ../src/train_mnist_cnn.py --epochs 3
